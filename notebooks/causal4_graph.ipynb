# %%
import pandas as pd

# %%
df = pd.read_csv("causal4_searchlight_results.csv", index_col=0)

# %%
df
# Out:
#                 long_name  type               roi  speech_responsive  \
# 9610           Temporal75  grid  superiortemporal               True
# 9611           Temporal76  grid  superiortemporal               True
# 2500           Inferior69  grid  superiortemporal               True
# 4134           Superior39  grid        precentral               True
# 4627       AnteriorGrid20  grid  superiortemporal               True
# ...                   ...   ...               ...                ...
# 9200          Temporal113  grid        precentral               True
# 2318           Superior15  grid       postcentral               True
# 1369   InferiorParietal90  grid  superiortemporal               True
# 17487         Temporal112  grid     supramarginal               True
# 6499      AnteriorGrid100  grid  superiortemporal               True
#
#        control_corr_left  control_corr_right  control_p_val_left  \
# 9610            0.079360           -0.123747            0.591839
# ...

# %%
df["source"] = df.subject + " " + df.population_A.astype(str)

# %%
df.source.value_counts()
# Out:
# source
# EC253 0    47
# EC250 6    22
# EC243 6    18
# EC260 5    17
# EC287 5    17
# EC282 3    12
# EC270 0    12
# EC270 5    11
# EC250 5     8
# EC282 6     8
# EC282 0     8
# EC253 5     8
# EC270 3     8
# EC282 5     2
# Name: count, dtype: int64
